# %% [markdown]
# # Day 14 - Final Machine Learning Model Comparison
#
# ## AI & ML Internship - Codomax Digital Solutions
#
# **Name:** Mohammed Sanjidh
#
# This notebook summarizes the complete 14-day AI & Machine Learning internship by comparing different machine learning models used for Student Score Prediction and Student Pass/Fail Classification.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
regression_results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "MAE": [
        4.18,
        5.10,
        3.82
    ],
    "RMSE": [
        5.10,
        6.42,
        4.70
    ],
    "R² Score": [
        0.96,
        0.93,
        0.97
    ]
})

regression_results
# Out:
#                Model   MAE  RMSE  R² Score
# 0  Linear Regression  4.18  5.10      0.96
# 1      Decision Tree  5.10  6.42      0.93
# 2      Random Forest  3.82  4.70      0.97

# %%
plt.figure(figsize=(8,5))

plt.bar(
    regression_results["Model"],
    regression_results["R² Score"]
)

plt.title("Regression Model Comparison")

plt.xlabel("Models")

plt.ylabel("R² Score")

plt.grid(axis="y")

plt.show()

# %%
classification_results = pd.DataFrame({
    "Model":[
        "Logistic Regression",
        "KNN"
    ],
    "Accuracy":[
        0.90,
        0.95
    ]
})

classification_results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression      0.90
# 1                  KNN      0.95

# %%
plt.figure(figsize=(6,4))

plt.bar(
    classification_results["Model"],
    classification_results["Accuracy"]
)

plt.title("Classification Model Comparison")

plt.ylabel("Accuracy")

plt.grid(axis="y")

plt.show()

# %% [markdown]
# # Internship Summary
#
# | Day | Topic |
# |------|------------------------------|
# | Day 1 | Environment Setup |
# | Day 2 | Python Basics |
# | Day 3 | NumPy |
# | Day 4 | Pandas |
# | Day 5 | Data Cleaning |
# | Day 6 | Data Visualization |
# | Day 7 | Linear Regression |
# | Day 8 | Model Evaluation |
# | Day 9 | Model Persistence |
# | Day 10 | Decision Tree Regression |
# | Day 11 | Random Forest Regression |
# | Day 12 | Logistic Regression |
# | Day 13 | KNN Classification |
# | Day 14 | Final Model Comparison |

# %% [markdown]
# # Key Learnings
#
# - Python Programming
# - NumPy
# - Pandas
# - Data Cleaning
# - Data Visualization
# - Linear Regression
# - Decision Tree Regression
# - Random Forest Regression
# - Logistic Regression
# - KNN Classification
# - Model Evaluation
# - Git & GitHub
# - Jupyter Notebook

# %% [markdown]
# # Conclusion
#
# This internship helped me build a strong foundation in Machine Learning by covering data preprocessing, visualization, regression, classification, and model evaluation.
#
# Through daily hands-on practice, I gained practical experience implementing and comparing multiple machine learning algorithms using Python and Scikit-learn.
#
# This journey has strengthened my confidence in applying Machine Learning concepts to real-world problems and has inspired me to continue exploring Artificial Intelligence and Data Science.
